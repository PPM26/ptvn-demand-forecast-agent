# %%
import pandas as pd
df = pd.read_csv("demand_forecast_db.csv")
df.tail()
# Out:
#                      forecast_date  \
# 245  2024-09-29 00:00:00.000 +0700
# 246  2024-09-29 00:00:00.000 +0700
# 247  2024-09-29 00:00:00.000 +0700
# 248  2024-09-29 00:00:00.000 +0700
# 249  2024-09-29 00:00:00.000 +0700
#
#                                               subgroup          categorylv5  \
# 245                                            Chicken              ยอไก่ยอ
# 246                             Healthcare Supplements    สารเลี้ยงน้ำเชื้อ
# 247                                          Laminator  เครื่องเคลือบเอกสาร
# 248                                     Bench Grinders        เครื่องเจียร์
# 249  Air Conditioning Installation Or Maintenance O...     เดินท่อน้ำยาแอร์
#
#       demand_type                                  product_synthetic  \
# 245  Intermittent  ยอไก่ยอ เป็นผลิตภัณฑ์จากเนื้อไก่คุณภาพเยี่ยม เ...
# 246  Intermittent  สารเลี้ยงน้ำเชื้อ เป็นผลิตภัณฑ์เสริมสุขภาพที่อ...
# 247  Intermittent  เครื่องเคลือบเอกสารรุ่นนี้เหมาะสำหรับใช้งานในส...
# ...

# %%
df.shape
# Out:
# (250, 6)

# %%
temp = df[368:416]
temp.head(20)
# Out:
# Empty DataFrame
# Columns: [forecast_date, subgroup, categorylv5, demand_type, product_synthetic, demand_forecast]
# Index: []

# %%
temp.to_csv("demand_forecast.csv", index=False)

# %%
temp.columns
# Out:
# Index(['forecast_date', 'subgroup', 'categorylv5', 'demand_type',
#        'product_synthetic', 'demand_forecast'],
#       dtype='object')
